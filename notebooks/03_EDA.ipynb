# %%
from src.basedatos.gestor_basedatos import GestorBaseDatos
from src.eda.procesador_eda import ProcesadorEDA

# %%
gestor = GestorBaseDatos("postgresql+psycopg2://incofer:incofer_dev_password@localhost:5432/incofer")
df = gestor.consultar("SELECT * FROM viajes_diarios")
gestor.cerrar()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 gestor = GestorBaseDatos("postgresql+psycopg2://incofer:incofer_dev_password@localhost:5432/incofer")
# ----> 2 df = gestor.consultar("SELECT * FROM viajes_diarios")
#       3 gestor.cerrar()
#
# File ~\Documents\BigData\PrograII\ExamenIII\Incofer-Costa-Rica-optimization-and-demand-prediction\src\basedatos\gestor_basedatos.py:87, in GestorBaseDatos.consultar(self, sql, params)
#      82 def consultar (self, sql: str, params: dict | None = None) -> pd.DataFrame:
#      83     """Ejecuta un SELECT y devuelve el resultado como DataFrame.
#      84     `params` permite pasar valores de forma segura (evita SQL injection)
#      85     usando placeholders con nombre, ej: ':anio' en el SQL y
#      86     params={'anio': 2024}."""
# ---> 87     return pd.read_sql(text(sql), self.engine, params=params)
#
# File ~\Documents\BigData\PrograII\ExamenIII\Incofer-Costa-Rica-optimization-and-demand-prediction\.venv\Lib\site-packages\pandas\io\sql.py:730, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     720     return pandas_sql.read_table(
#     721         sql,
#     722         index_col=index_col,
#    (...)    727         dtype_backend=dtype_backend,
#     728     )
#     729 else:
# --> 730     return pandas_sql.read_query(
#     731         sql,
#     732         index_col=index_col,
#     733         params=params,
#     734         coerce_float=coerce_float,
#     735         parse_dates=parse_dates,
#     736         chunksize=chunksize,
#     737         dtype_backend=dtype_backend,
#     738         dtype=dtype,
#     739     )
#
# File ~\Documents\BigData\PrograII\ExamenIII\Incofer-Costa-Rica-optimization-and-demand-prediction\.venv\Lib\site-packages\pandas\io\sql.py:1874, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1872 else:
#    1873     data = result.fetchall()
# -> 1874     frame = _wrap_result(
#    1875         data,
#    1876         columns,
#    1877         index_col=index_col,
#    1878         coerce_float=coerce_float,
#    1879         parse_dates=parse_dates,
#    1880         dtype=dtype,
#    1881         dtype_backend=dtype_backend,
#    1882     )
#    1883     return frame
#
# File ~\Documents\BigData\PrograII\ExamenIII\Incofer-Costa-Rica-optimization-and-demand-prediction\.venv\Lib\site-packages\pandas\io\sql.py:205, in _wrap_result(data, columns, index_col, coerce_float, parse_dates, dtype, dtype_backend)
#     195 def _wrap_result(
#     196     data,
#     197     columns,
#    (...)    202     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#     203 ) -> DataFrame:
#     204     """Wrap result set of a SQLAlchemy query in a DataFrame."""
# --> 205     frame = _convert_arrays_to_dataframe(data, columns, coerce_float, dtype_backend)
#     207     if dtype:
#     208         frame = frame.astype(dtype)
#
# File ~\Documents\BigData\PrograII\ExamenIII\Incofer-Costa-Rica-optimization-and-demand-prediction\.venv\Lib\site-packages\pandas\io\sql.py:168, in _convert_arrays_to_dataframe(data, columns, coerce_float, dtype_backend)
#     166 content = lib.to_object_array_tuples(data)
#     167 idx_len = content.shape[0]
# --> 168 arrays = convert_object_array(
#     169     list(content.T),
#     170     dtype=None,
#     171     coerce_float=coerce_float,
#     172     dtype_backend=dtype_backend,
#     173 )
#     174 if dtype_backend == "pyarrow":
#     175     pa = import_optional_dependency("pyarrow")
#
# File ~\Documents\BigData\PrograII\ExamenIII\Incofer-Costa-Rica-optimization-and-demand-prediction\.venv\Lib\site-packages\pandas\core\internals\construction.py:1053, in convert_object_array(content, dtype, dtype_backend, coerce_float)
#    1049             arr = maybe_cast_to_datetime(arr, dtype)
#    1051     return arr
# -> 1053 arrays = [convert(arr) for arr in content]
#    1055 return arrays
#
# File ~\Documents\BigData\PrograII\ExamenIII\Incofer-Costa-Rica-optimization-and-demand-prediction\.venv\Lib\site-packages\pandas\core\internals\construction.py:1020, in convert_object_array.<locals>.convert(arr)
#    1017 if arr.dtype == np.dtype("O"):
#    1018     # i.e. maybe_convert_objects didn't convert
#    1019     convert_to_nullable_dtype = dtype_backend != "numpy"
# -> 1020     arr = lib.maybe_convert_objects(
#    1021         arr,
#    1022         # Here we do not convert numeric dtypes, as if we wanted that,
#    1023         #  numpy would have done it for us.
#    1024         convert_numeric=False,
#    1025         convert_non_numeric=True,
#    1026         convert_to_nullable_dtype=convert_to_nullable_dtype,
#    1027         dtype_if_all_nat=np.dtype("M8[s]"),
#    1028     )
#    1029     if convert_to_nullable_dtype and arr.dtype == np.dtype("O"):
#    1030         new_dtype = StringDtype()
#
# File pandas/_libs/lib.pyx:2784, in pandas._libs.lib.maybe_convert_objects()
# -> 2784 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~\Documents\BigData\PrograII\ExamenIII\Incofer-Costa-Rica-optimization-and-demand-prediction\.venv\Lib\site-packages\pandas\core\indexes\datetimes.py:702, in DatetimeIndex.__new__(cls, data, freq, tz, ambiguous, dayfirst, yearfirst, dtype, copy, name)
#     699         data = data.copy()
#     700     return cls._simple_new(data, name=name)
# --> 702 dtarr = DatetimeArray._from_sequence_not_strict(
#     703     data,
#     704     dtype=dtype,
#     705     copy=copy,
#     706     tz=tz,
#     707     freq=freq,
#     708     dayfirst=dayfirst,
#     709     yearfirst=yearfirst,
#     710     ambiguous=ambiguous,
#     711 )
#     712 refs = None
#     713 if not copy and isinstance(data, (Index, ABCSeries)):
#
# File ~\Documents\BigData\PrograII\ExamenIII\Incofer-Costa-Rica-optimization-and-demand-prediction\.venv\Lib\site-packages\pandas\core\arrays\datetimes.py:381, in DatetimeArray._from_sequence_not_strict(cls, data, dtype, copy, tz, freq, dayfirst, yearfirst, ambiguous)
#     378 if isinstance(data, DatetimeArray):
#     379     inferred_freq = data.freq
# --> 381 subarr, tz = _sequence_to_dt64(
#     382     data,
#     383     copy=copy,
#     384     tz=tz,
#     385     dayfirst=dayfirst,
#     386     yearfirst=yearfirst,
#     387     ambiguous=ambiguous,
#     388     out_unit=unit,
#     389 )
#     390 # We have to call this again after possibly inferring a tz above
#     391 _validate_tz_from_dtype(dtype, tz, explicit_tz_none)
#
# File ~\Documents\BigData\PrograII\ExamenIII\Incofer-Costa-Rica-optimization-and-demand-prediction\.venv\Lib\site-packages\pandas\core\arrays\datetimes.py:2472, in _sequence_to_dt64(data, copy, tz, dayfirst, yearfirst, ambiguous, out_unit)
#    2470     return result, tz
#    2471 else:
# -> 2472     converted, inferred_tz = objects_to_datetime64(
#    2473         data,
#    2474         dayfirst=dayfirst,
#    2475         yearfirst=yearfirst,
#    2476         allow_object=False,
#    2477         out_unit=out_unit,
#    2478     )
#    2479     copy = False
#    2480     if tz and inferred_tz:
#    2481         #  two timezones: convert to intended from base UTC repr
#    2482         # GH#42505 by convention, these are _already_ UTC
#
# File ~\Documents\BigData\PrograII\ExamenIII\Incofer-Costa-Rica-optimization-and-demand-prediction\.venv\Lib\site-packages\pandas\core\arrays\datetimes.py:2578, in objects_to_datetime64(data, dayfirst, yearfirst, utc, errors, allow_object, out_unit)
#    2573     result = data
#    2575     return result, copy
# -> 2578 def objects_to_datetime64(
#    2579     data: np.ndarray,
#    2580     dayfirst,
#    2581     yearfirst,
#    2582     utc: bool = False,
#    2583     errors: DateTimeErrorChoices = "raise",
#    2584     allow_object: bool = False,
#    2585     out_unit: str | None = None,
#    2586 ) -> tuple[np.ndarray, tzinfo | None]:
#    2587     """
#    2588     Convert data to array of timestamps.
#    2589
#    (...)   2616     TypeError  : When a type cannot be converted to datetime
#    2617     """
#    2618     assert errors in ["raise", "coerce"]
#
# KeyboardInterrupt:

# %%
eda = ProcesadorEDA(df)
eda.resumen_general()
print(eda.rutas_saturadas())
print(eda.correlacion_clima_pasajeros())
# Out:
# filas: 21874
# rango_fechas: (Timestamp('2021-01-18 00:00:00'), Timestamp('2026-06-30 00:00:00'))
# recorridos_distintos: 8
# pct_pasajeros_nulos: 0.0
# pct_clima_nulo: 0.0
# dias_feriado: 41
#               recorrido_normalizado  promedio_pasajeros_diarios
# 0  ESTACION DEL ATLANTICO - CARTAGO                 2216.385516
#                    pasajeros_totales  temp_max_c  temp_min_c  precipitacion_mm
# pasajeros_totales           1.000000   -0.212777   -0.220982         -0.044692
# temp_max_c                 -0.212777    1.000000    0.209548         -0.328900
# temp_min_c                 -0.220982    0.209548    1.000000          0.109206
# precipitacion_mm           -0.044692   -0.328900    0.109206          1.000000

# %%
eda.estadisticas_descriptivas()
# Out:
#        pasajeros_regulares  adultos_mayores  pasajeros_totales  \
# count         20674.000000     21874.000000       21874.000000
# mean            764.262600        17.003794         739.339216
# std             947.022156        49.808426         970.466947
# min               1.000000         0.000000           0.000000
# 25%             199.000000         0.000000         161.000000
# 50%             369.000000         0.000000         354.000000
# 75%             806.750000         0.000000         757.750000
# max           11393.000000       528.000000       11393.000000
#
#        ingresos_colones    temp_max_c    temp_min_c  precipitacion_mm
# count      2.067300e+04  21874.000000  21874.000000      21874.000000
# mean       9.484993e+05     25.065100     16.471263          6.952199
# std        3.275503e+06      2.038355      1.346072         11.285300
# min        2.400000e+02     16.000000      8.300000          0.000000
# 25%        1.062000e+05     23.700000     15.700000          0.200000
# 50%        2.108200e+05     25.100000     16.600000          1.800000
# 75%        5.250000e+05     26.300000     17.400000          9.400000
# max        5.035800e+07     31.300000     20.600000        101.600000

# %%
print(df['adultos_mayores_faltante'].sum(), 'de', len(df))
print(df['adultos_mayores_faltante'].mean())
# Out:
# 16995 de 21874
# 0.7769498034195849

# %%
eda.demanda_por_dia_semana()
# Out:
#    dia_semana nombre_dia    promedio      total  dias_observados
# 0           0     Monday  752.421523  3202306.0             4256
# 1           1    Tuesday  780.861446  3370198.0             4316
# 2           2  Wednesday  754.943216  3243991.0             4297
# 3           3   Thursday  735.630903  3208822.0             4362
# 4           4     Friday  676.420956  2943784.0             4352
# 5           5   Saturday  636.577320   123496.0              194
# 6           6     Sunday  821.742268    79709.0               97

# %%
eda.impacto_feriados()
# Out:
#    es_feriado    promedio       total   dias
# 0       False  754.876654  16028296.0  21233
# 1        True  224.664587    144010.0    641

# %%
eda.detectar_outliers()
# Out:
#            fecha  anio  mes  dia  dia_semana nombre_dia  es_fin_de_semana  \
# 18228 2025-08-02  2025    8    2           5   Saturday              True
# 6060  2022-08-02  2022    8    2           1    Tuesday             False
# 10072 2023-08-02  2023    8    2           2  Wednesday             False
# 14181 2024-08-02  2024    8    2           4     Friday             False
# 18213 2025-08-01  2025    8    1           4     Friday             False
# ...          ...   ...  ...  ...         ...        ...               ...
# 15203 2024-10-31  2024   10   31           3   Thursday             False
# 5435  2022-06-08  2022    6    8           2  Wednesday             False
# 15890 2025-01-14  2025    1   14           1    Tuesday             False
# 11687 2023-12-22  2023   12   22           4     Friday             False
# 5932  2022-07-21  2022    7   21           3   Thursday             False
#
#       codigo_ruta                              ruta codigo_recorrido  ...  \
# 18228       RF004  ESTACION DEL ATLANTICO - CARTAGO            T4470  ...
# 6060        RF004  ESTACION DEL ATLANTICO - CARTAGO            T4470  ...
# 10072       RF004  ESTACION DEL ATLANTICO - CARTAGO            T4470  ...
# 14181       RF004  ESTACION DEL ATLANTICO - CARTAGO            T4470  ...
# 18213       RF004  ESTACION DEL ATLANTICO - CARTAGO            T4470  ...
# ...           ...                               ...              ...  ...
# 15203       RF003      UNIVERSIDAD LATINA - HEREDIA            T4469  ...
# 5435        RF003      UNIVERSIDAD LATINA - HEREDIA            T4469  ...
# 15890       RF003      UNIVERSIDAD LATINA - HEREDIA            T4469  ...
# 11687       RF004  ESTACION DEL ATLANTICO - CARTAGO            T4470  ...
# 5932        RF004  ESTACION DEL ATLANTICO - CARTAGO            T4470  ...
#
#       ingresos_colones pasajeros_regulares_faltante ingresos_faltante  \
# 18228        8032065.0                        False             False
# 6060         6095650.0                        False             False
# 10072        7656300.0                        False             False
# 14181        7339050.0                        False             False
# 18213        3957165.0                        False             False
# ...                ...                          ...               ...
# 15203         840935.0                        False             False
# 5435          697620.0                        False             False
# 15890         904155.0                        False             False
# 11687        1169595.0                        False             False
# 5932          910800.0                        False             False
#
#        adultos_mayores_faltante  ciudad_clima  \
# 18228                      True       Cartago
# 6060                       True       Cartago
# 10072                      True       Cartago
# 14181                     False       Cartago
# 18213                     False       Cartago
# ...                         ...           ...
# 15203                     False       Heredia
# 5435                       True       Heredia
# 15890                      True       Heredia
# 11687                      True       Cartago
# 5932                       True       Cartago
#
#                                   nombre_local  es_feriado  temp_max_c  \
# 18228  Fiesta de Nuestra Señora de los Ángeles        True        21.4
# 6060   Fiesta de Nuestra Señora de los Ángeles        True        21.6
# 10072  Fiesta de Nuestra Señora de los Ángeles        True        22.6
# 14181  Fiesta de Nuestra Señora de los Ángeles        True        23.7
# 18213                                                False        23.3
# ...                                        ...         ...         ...
# 15203                                                False        21.9
# 5435                                                 False        23.4
# 15890                                                False        24.4
# 11687                                                False        21.2
# 5932                                                 False        21.9
#
#        temp_min_c  precipitacion_mm
# 18228        15.7               5.0
# 6060         14.3              27.1
# 10072        15.8               2.1
# 14181        13.5               9.1
# 18213        15.0               0.1
# ...           ...               ...
# 15203        17.6              12.4
# 5435         16.7              11.5
# 15890        13.8               1.0
# 11687        16.3               4.6
# 5932         16.0               4.0
#
# [3707 rows x 26 columns]
